# %%
## Gravity model to predict the intercity medical patient flow, affected by the relative relationship of distance, health resource, and affordability between origins and destinations
## distance: railway shortest distance matrix estimated by China 1:100 million public dataset
## health resource: number of hospital beds and clinics in each city
## affordability: GDP per capita in each city
## author: Shiyu Deng
## data: January 2026
## affiliation: University College London (UCL)
## email: shiyu.deng.23@ucl.ac.uk


##------ Calculate GDP matrix --------

import pandas as pd
import numpy as np
import glob
import os


input_folder = "/weighted_gdp"
output_folder = "/gdp_matrix"
os.makedirs(output_folder, exist_ok=True)

def coerce_numeric(series: pd.Series) -> pd.Series:
    """
    Force a column containing commas, spaces, and possible units or
    miscellaneous characters to float.
    Invalid values are converted to NaN.
    """
    s = series.astype(str)

    s = s.str.replace(',', '', regex=False).str.replace(' ', '', regex=False)
    s = s.str.extract(r'([-+]?\d*\.?\d+(?:[eE][-+]?\d+)?)', expand=False)
    return pd.to_numeric(s, errors='coerce')


for file in glob.glob(os.path.join(input_folder, "*.csv")):
    print("Processing:", file)
    
    df = pd.read_csv(file)
    df = df.rename(columns=str.lower)  
    if "city" not in df.columns or "pc_gdp" not in df.columns:
        print("⚠️ File missing 'city' or 'pc_gdp' column, skipped:", file)
        continue

    city_col = "city" if "city" in df.columns else None
    gdp_col  = "pc_gdp" if "pc_gdp" in df.columns else None
    
    df = df[[city_col, gdp_col]].rename(columns={city_col: "city", gdp_col: "pc_gdp"})
    df["city"] = df["city"].astype(str).str.strip()
    df["pc_gdp"] = coerce_numeric(df["pc_gdp"])
    df = df.dropna(subset=["city", "pc_gdp"])
    print(df[df["pc_gdp"] <= 0])

    gdp = df["pc_gdp"].to_numpy()
    cities = df["city"].to_numpy()

    matrix = gdp[None, :] / gdp[:, None]
    reject_df = pd.DataFrame(matrix, index=cities, columns=cities)
    np.fill_diagonal(reject_df.values, np.nan)
    

    base = os.path.basename(file).replace(".csv", "")
    out_csv1 = os.path.join(output_folder, f"{base}_reject_matrix.csv")


    reject_df.to_csv(out_csv1)
    print(f"✅ Matrix saved: {out_csv1}")

# %%
##------ Calculate city-level medical resource representative matrix --------

import pandas as pd
import numpy as np
import os


INPUT_FILE = (
    "/National hospital directory.xlsx"
)  

OUTPUT_FILE = (
    "/city_medical_resources.xlsx"
)  

df = pd.read_excel(INPUT_FILE, sheet_name="destination hospital")
print(df.columns.tolist())

df_use = df[["city", "hospital name", "beds", "clinics"]].copy()


df_use["beds"] = pd.to_numeric(df_use["beds"], errors="coerce")
df_use["clinics"] = pd.to_numeric(df_use["clinics"], errors="coerce")

df_use = df_use.dropna(subset=["city", "beds", "clinics"])
df_use = df_use[(df_use["beds"] > 0) & (df_use["clinics"] > 0)]


df_use["hospital_resource_value"] = df_use["beds"] * df_use["clinics"]
df_use["hospital_resource_value_log"] = (
    np.log(df_use["beds"]) * np.log(df_use["clinics"])
)


agg = (
    df_use.groupby("city", as_index=False)
    .agg(
        hospital_count=("hospital name", "count"),
        resource_value=("hospital_resource_value", "sum"),
    )
)
with pd.ExcelWriter(OUTPUT_FILE, engine="xlsxwriter") as writer:
    df_use.to_excel(writer, sheet_name="Hospital", index=False)
    agg.sort_values("hospital_resource_value", ascending=False).to_excel(
        writer, sheet_name="City", index=False
    )

# %%
## calculate railway shortest distance matrix between cities 

# !pip install rasterio geopandas networkx numpy

import os
import numpy as np
import rasterio
import geopandas as gpd
import networkx as nx
from shapely.geometry import Point
from math import sqrt
from tqdm import tqdm
import pandas as pd
from collections import defaultdict

# ========= Configuration =========
rail_tif = "/railroad_c.tif"              # Railway raster (must be GeoTIFF in a projected CRS with meter units)
cities_file = "/shi_en.shp"               # City point shapefile (CSV is also possible, see note below)
city_name_col = "City"                    # City name field
use_8_conn = True                         # Use 8-neighbor (diagonal) connectivity
rail_values = {1}                         # Raster values representing railway cells (adjust for your data)
search_radius = 50                        # Max search radius (in pixels) to snap cities to nearest railway cell
out_csv_long = "/rail_distance_pairs.csv"     # Long table: source, target, distance_km
out_csv_wide = "/rail_distance_matrix.csv"    # Wide table: distance matrix (rows/cols = cities)

os.makedirs("out", exist_ok=True)

with rasterio.open(rail_tif) as src:
    rail = src.read(1)
    transform = src.transform
    crs = src.crs
    px = abs(transform.a)
    py = abs(transform.e)
    step = (px + py) / 2.0

if crs.is_geographic:
    raise ValueError(
        "rail.tif is in geographic coordinates (degrees). "
        "Please reproject it to a projected CRS in meters (e.g. EPSG:3857 or EPSG:4547) before running."
    )


mask = np.isin(rail, list(rail_values))
idx_r, idx_c = np.where(mask)
if len(idx_r) == 0:
    raise ValueError("No railway cells found. Please check rail_values.")

# ========= Build railway graph =========
G = nx.Graph()
dirs4 = [(-1, 0), (1, 0), (0, -1), (0, 1)]
dirs8 = dirs4 + [(-1, -1), (-1, 1), (1, -1), (1, 1)]
dirs = dirs8 if use_8_conn else dirs4

def arc_w(dr, dc):
    return step * (sqrt(2) if abs(dr) == 1 and abs(dc) == 1 else 1.0)

rail_bool = mask
H, W = rail.shape

# Only iterate over railway cells and connect neighboring railway cells
for i, j in zip(idx_r, idx_c):
    node = (i, j)
    G.add_node(node)
    for dr, dc in dirs:
        ni, nj = i + dr, j + dc
        if 0 <= ni < H and 0 <= nj < W and rail_bool[ni, nj]:
            G.add_edge(node, (ni, nj), weight=arc_w(dr, dc))

print(f"Graph built: nodes={G.number_of_nodes()}, edges={G.number_of_edges()}")


cities = gpd.read_file(cities_file)
if cities.crs is None:
    raise ValueError("City data has no CRS. Please make sure a coordinate system is defined.")

# Reproject cities to match railway CRS (must be in meters)
cities = cities.to_crs(crs)

# ========= Coordinate <-> raster index conversion =========
def xy_to_rowcol(x, y, transform):
    col, row = ~transform * (x, y)
    return int(round(row)), int(round(col))

# ========= Find nearest railway cell =========
def nearest_rail_cell(r, c, mask, max_search=50):
    if 0 <= r < mask.shape[0] and 0 <= c < mask.shape[1] and mask[r, c]:
        return (r, c)
    for rad in range(1, max_search + 1):
        rmin, rmax = max(0, r - rad), min(mask.shape[0] - 1, r + rad)
        cmin, cmax = max(0, c - rad), min(mask.shape[1] - 1, c + rad)
        sub = mask[rmin:rmax + 1, cmin:cmax + 1]
        if sub.any():
            rr, cc = np.where(sub)
            rr0, cc0 = rr[0] + rmin, cc[0] + cmin
            return (rr0, cc0)
    return None

city_nodes = {}
for idx, row in cities.iterrows():
    name = str(row[city_name_col])
    x, y = row.geometry.x, row.geometry.y
    r, c = xy_to_rowcol(x, y, transform)
    node = nearest_rail_cell(r, c, rail_bool, max_search=search_radius)
    if node is None:
        print(f"[Warning] No railway cell found near city {name} (radius={search_radius}). Skipped.")
    else:
        city_nodes[name] = node

valid_names = list(city_nodes.keys())
print(f"Cities used in calculation: {len(valid_names)} / {len(cities)}")

# ========= Multi-source shortest paths (Dijkstra per city) =========
pairs = []  # (source, target, distance_km)

for s in tqdm(valid_names, desc="Dijkstra by city"):
    src_node = city_nodes[s]
    dist_dict = nx.single_source_dijkstra_path_length(
        G, src_node, weight="weight"
    )
    for t in valid_names:
        if t == s:
            continue
        dst_node = city_nodes[t]
        d = dist_dict.get(dst_node)
        if d is not None:
            pairs.append((s, t, d / 1000.0))  # meters -> kilometers

# ========= Output: long table =========
df_long = pd.DataFrame(
    pairs, columns=["source_city", "target_city", "distance_km"]
)
df_long.to_csv(out_csv_long, index=False, encoding="utf-8-sig")
print(f"Long table saved to: {out_csv_long}")

# ========= Optional: symmetric distance matrix =========
cities_sorted = sorted(valid_names)
mat = pd.DataFrame(np.nan, index=cities_sorted, columns=cities_sorted)

for s, t, d in pairs:
    mat.loc[s, t] = d
    mat.loc[t, s] = d  # assume undirected / symmetric

np.fill_diagonal(mat.values, 0.0)
mat.to_csv(out_csv_wide, encoding="utf-8-sig")
print(f"Distance matrix saved to: {out_csv_wide}")

# %%
##------ Calculate truncated power-law kernel matrix --------

import pandas as pd
import numpy as np

# ===== Parameters =====
INPUT_FILE = "/rail_distance_matrix.csv"   # Distance matrix file
SHEET_NAME = 0
BETA = 1.81
KPAR = 1758.5
TAIL_ONLY = False     # True = apply truncation only for r >= R_MIN; False = apply to all distances

# ===== 1) Read distance matrix D =====
D = pd.read_csv(INPUT_FILE, index_col=0).astype(float)
np.fill_diagonal(D.values, np.nan)

# ===== 2) Compute truncated power-law kernel K =====
with np.errstate(divide='ignore', invalid='ignore'):
    K = (D ** (-BETA))

if TAIL_ONLY:
    K = K * np.exp(-D / KPAR)


K.to_csv("/kernel_trunc_powerlaw_matrix.csv", float_format="%.6g")

print( 
    "✅ Completed:",
    "\n- Kernel matrix saved as: kernel_trunc_powerlaw_matrix.csv"
)

# %%
##---- Compute cross-city patient flows ----------
import pandas as pd
import numpy as np
import os, glob

# ===== Paths and templates (as provided) =====
DIST_FILE = "/Volumes/UCL/论文工作/空气污染/city_distance/kernel_trunc_powerlaw_matrix_truncated.csv"  # rows/cols = cities

S_FILE    = "/Volumes/UCL/论文工作/空气污染/city_medical_resources.xlsx"  # contains city and resource column
S_COL     = "hospital_resource_value"

CITYSUM_DIR = "/Volumes/UCL/论文工作/空气污染/health_burden/air_scenarios_5/city_patient_sum"  # includes stroke after filtering
CITYSUM_TPL = "citysum_{air}_{year}.csv"

G_DIR  = "/Volumes/UCL/论文工作/空气污染/weighted_gdp/gdp_matrix"
G_TPL  = "city_pop_weighted_gdp_{year}_{fer}_{rcp}_reject_matrix.csv"  # order: year, fer, rcp

OUT_DIR = "/Volumes/UCL/论文工作/空气污染/cross_flow_truncated"
os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "aij_results"), exist_ok=True)
os.makedirs(os.path.join(OUT_DIR, "flow_results"), exist_ok=True)

# ===== Scenario sets =====
air_scenarios = ['earlypeak_NZ_CL']
fer_scenarios = ['low', 'mid', 'high']
rcp_scenarios = ['RCP2_6', 'RCP4_5', 'RCP8_5']
years = list(range(2020, 2061, 10))


def read_S_from_excel(xlsx_path: str, value_col: str) -> pd.DataFrame:
    """Read a table containing columns 'city' and value_col from any sheet in an Excel file."""
    xls = pd.ExcelFile(xlsx_path)
    for sh in xls.sheet_names:
        df = pd.read_excel(xlsx_path, sheet_name=sh)
        cols = [c.strip() if isinstance(c, str) else c for c in df.columns]
        df.columns = cols
        if "city" in df.columns and value_col in df.columns:
            out = df[["city", value_col]].copy()
            out["city"] = out["city"].astype(str).str.strip()
            return out
    raise ValueError(f"Could not find columns 'city' and '{value_col}' in any sheet of {xlsx_path}")

# ===== Fixed inputs =====
D_full = pd.read_csv(DIST_FILE, index_col=0).astype(float)

if not np.isnan(np.diag(D_full.values)).all():
    np.fill_diagonal(D_full.values, np.nan)

# Medical resources (162 target cities)
S_df = read_S_from_excel(S_FILE, S_COL)
targets_168 = S_df["city"].tolist()
S_full = S_df.set_index("city")[S_COL].astype(float)

# ===== Main loop =====
for air in air_scenarios:
    for fer in fer_scenarios:
        for rcp in rcp_scenarios:
            for year in years:

                # --- V: define sources based on citysum (360) ---
                v_path = os.path.join(CITYSUM_DIR, CITYSUM_TPL.format(air=air, fer=fer, rcp=rcp, year=year))
                v_files = glob.glob(v_path)
                if not os.path.exists(v_path):
                    print(f"⚠️ V file not found: {v_path}")
                    continue 

                Vdf = pd.read_csv(v_files[0])
                city_col = "city" if "city" in Vdf.columns else Vdf.columns[0]
                vcol = "local_patient"
                Vdf[city_col] = Vdf[city_col].astype(str).str.strip()
                sources_360 = Vdf[city_col].tolist()

                # --- G: read and align to (sources × targets) ---
                g_path = os.path.join(G_DIR, G_TPL.format(year=year, fer=fer, rcp=rcp))
                g_files = glob.glob(g_path)
                if not os.path.exists(g_path):
                    print(f"⚠️ G file not found: {g_path}")
                    continue 

                G_full = pd.read_csv(g_files[0], index_col=0)

                # Align: rows = intersection of (citysum 360) with G and D;
                #        cols = intersection of (targets 168) with G and D
                rows = [c for c in sources_360 if c in G_full.index and c in D_full.index]
                cols = [c for c in targets_168 if c in G_full.columns and c in D_full.columns]
                print(f"row cities (source): {rows} | col cities (targets): {cols}")

                # --- V_ratio: V_i / V_j ---
                lp_series = Vdf.set_index(city_col)[vcol].astype(float)
                LP_rows = lp_series.reindex(rows)
                LP_cols = lp_series.reindex(cols)
                V_ratio = LP_rows.values[:, None] / LP_cols.values[None, :]
                print("V_ratio", V_ratio)

                G = G_full.loc[rows, cols].copy()
                D = D_full.loc[rows, cols].copy()

                # --- S_j: keep only target cities ---
                S_vec = S_full.reindex(cols).astype(float).values

                # --- Compute a_ij = (G_ij * S_j * D_ij ---
                # Note: The current implementation below does NOT multiply by V_ratio.
                A = G.values * S_vec[None, :] * D.values
                A = pd.DataFrame(A, index=rows, columns=cols)

                # --- Row-normalize by j for each i (row normalization) ---
                row_sum = A.sum(axis=1).replace(0, np.nan)
                A_rowprob = A.div(row_sum, axis=0).fillna(0.0)

                # --- Save a_ij ---
                tag = f"{air}_{fer}_{rcp}_{year}"
                A_rowprob.to_csv(
                    os.path.join(OUT_DIR, f"aij_results/aij_rowprob_{tag}.csv"),
                    float_format="%.8g"
                )
                print(f"✅ a_ij matrix saved: {tag}  | shape={A_rowprob.shape}")

                # === Compute the actual flow matrix F_ij (number of patients) ===
                C_vec = Vdf.set_index(city_col)["cross_patient_total"].astype(float).reindex(rows)
                F = A_rowprob.mul(C_vec, axis=0)
                F.to_csv(
                    os.path.join(OUT_DIR, f"flow_results/flow_patientnum_{tag}.csv"),
                    float_format="%.8g"
                )
                print(f"✅ Patient flow matrix saved: {tag}  | shape={F.shape}")
# Out:
# ⚠️ G file not found: /Volumes/UCL/论文工作/空气污染/weighted_gdp/gdp_matrix/city_pop_weighted_gdp_2020_low_RCP2_6_reject_matrix.csv
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00920723 0.02917179 0.00738158 ... 0.02226103 0.10524253 0.03197103]
#  [0.06033543 0.19116414 0.04837184 ... 0.14587761 0.68965937 0.20950771]
#  [0.00444391 0.01407989 0.00356275 ... 0.01074438 0.05079575 0.01543095]
#  ...
#  [0.11227291 0.35572056 0.09001091 ... 0.27145083 1.28332655 0.3898545 ]
#  [0.13442401 0.42590313 0.10776978 ... 0.32500724 1.53652295 0.4667716 ]
#  [0.11591558 0.36726182 0.09293129 ... 0.28025798 1.32496376 0.40250323]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP2_6_2030  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP2_6_2030  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00709944 0.02404412 0.00641634 ... 0.02181902 0.08951981 0.02967381]
#  [0.06239703 0.21132404 0.05639326 ... 0.19176757 0.78679053 0.26080342]
#  [0.00602516 0.02040579 0.00544542 ... 0.01851738 0.07597375 0.0251836 ]
#  ...
#  [0.07471973 0.25305813 0.06753028 ... 0.22963948 0.94217271 0.31230913]
#  [0.08183843 0.27716749 0.07396403 ... 0.2515177  1.03193541 0.34206346]
#  [0.05681742 0.19242723 0.05135051 ... 0.17461952 0.71643492 0.23748212]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP2_6_2040  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP2_6_2040  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00834792 0.02703142 0.00849344 ... 0.02651793 0.10462722 0.03604731]
#  [0.08501404 0.27528416 0.08649596 ... 0.27005487 1.06550879 0.36710071]
#  [0.01057505 0.03424309 0.01075939 ... 0.03359261 0.13254056 0.04566432]
#  ...
#  [0.06149888 0.19913967 0.0625709  ... 0.19535682 0.77078561 0.26555946]
#  [0.06316329 0.20452918 0.06426432 ... 0.20064395 0.79164614 0.27274656]
#  [0.03765417 0.12192807 0.03831054 ... 0.11961193 0.47193209 0.16259519]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP2_6_2050  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP2_6_2050  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00804322 0.02818522 0.008237   ... 0.0360983  0.11738097 0.04407837]
#  [0.10764355 0.37720677 0.11023689 ... 0.48310866 1.57092621 0.58990708]
#  [0.01258634 0.04410533 0.01288957 ... 0.05648803 0.18368233 0.06897555]
#  ...
#  [0.03965583 0.13896278 0.04061121 ... 0.17797698 0.5787284  0.21732146]
#  [0.03697711 0.12957597 0.03786796 ... 0.16595479 0.53963581 0.20264159]
#  [0.00661772 0.02318997 0.00677716 ... 0.02970062 0.09657761 0.03626639]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP2_6_2060  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP2_6_2060  | shape=(360, 165)
# ⚠️ G file not found: /Volumes/UCL/论文工作/空气污染/weighted_gdp/gdp_matrix/city_pop_weighted_gdp_2020_low_RCP4_5_reject_matrix.csv
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00920723 0.02917179 0.00738158 ... 0.02226103 0.10524253 0.03197103]
#  [0.06033543 0.19116414 0.04837184 ... 0.14587761 0.68965937 0.20950771]
#  [0.00444391 0.01407989 0.00356275 ... 0.01074438 0.05079575 0.01543095]
#  ...
#  [0.11227291 0.35572056 0.09001091 ... 0.27145083 1.28332655 0.3898545 ]
#  [0.13442401 0.42590313 0.10776978 ... 0.32500724 1.53652295 0.4667716 ]
#  [0.11591558 0.36726182 0.09293129 ... 0.28025798 1.32496376 0.40250323]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP4_5_2030  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP4_5_2030  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00709944 0.02404412 0.00641634 ... 0.02181902 0.08951981 0.02967381]
#  [0.06239703 0.21132404 0.05639326 ... 0.19176757 0.78679053 0.26080342]
#  [0.00602516 0.02040579 0.00544542 ... 0.01851738 0.07597375 0.0251836 ]
#  ...
#  [0.07471973 0.25305813 0.06753028 ... 0.22963948 0.94217271 0.31230913]
#  [0.08183843 0.27716749 0.07396403 ... 0.2515177  1.03193541 0.34206346]
#  [0.05681742 0.19242723 0.05135051 ... 0.17461952 0.71643492 0.23748212]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP4_5_2040  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP4_5_2040  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00834792 0.02703142 0.00849344 ... 0.02651793 0.10462722 0.03604731]
#  [0.08501404 0.27528416 0.08649596 ... 0.27005487 1.06550879 0.36710071]
#  [0.01057505 0.03424309 0.01075939 ... 0.03359261 0.13254056 0.04566432]
#  ...
#  [0.06149888 0.19913967 0.0625709  ... 0.19535682 0.77078561 0.26555946]
#  [0.06316329 0.20452918 0.06426432 ... 0.20064395 0.79164614 0.27274656]
#  [0.03765417 0.12192807 0.03831054 ... 0.11961193 0.47193209 0.16259519]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP4_5_2050  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP4_5_2050  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00804322 0.02818522 0.008237   ... 0.0360983  0.11738097 0.04407837]
#  [0.10764355 0.37720677 0.11023689 ... 0.48310866 1.57092621 0.58990708]
#  [0.01258634 0.04410533 0.01288957 ... 0.05648803 0.18368233 0.06897555]
#  ...
#  [0.03965583 0.13896278 0.04061121 ... 0.17797698 0.5787284  0.21732146]
#  [0.03697711 0.12957597 0.03786796 ... 0.16595479 0.53963581 0.20264159]
#  [0.00661772 0.02318997 0.00677716 ... 0.02970062 0.09657761 0.03626639]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP4_5_2060  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP4_5_2060  | shape=(360, 165)
# ⚠️ G file not found: /Volumes/UCL/论文工作/空气污染/weighted_gdp/gdp_matrix/city_pop_weighted_gdp_2020_low_RCP8_5_reject_matrix.csv
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00920723 0.02917179 0.00738158 ... 0.02226103 0.10524253 0.03197103]
#  [0.06033543 0.19116414 0.04837184 ... 0.14587761 0.68965937 0.20950771]
#  [0.00444391 0.01407989 0.00356275 ... 0.01074438 0.05079575 0.01543095]
#  ...
#  [0.11227291 0.35572056 0.09001091 ... 0.27145083 1.28332655 0.3898545 ]
#  [0.13442401 0.42590313 0.10776978 ... 0.32500724 1.53652295 0.4667716 ]
#  [0.11591558 0.36726182 0.09293129 ... 0.28025798 1.32496376 0.40250323]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP8_5_2030  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP8_5_2030  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00709944 0.02404412 0.00641634 ... 0.02181902 0.08951981 0.02967381]
#  [0.06239703 0.21132404 0.05639326 ... 0.19176757 0.78679053 0.26080342]
#  [0.00602516 0.02040579 0.00544542 ... 0.01851738 0.07597375 0.0251836 ]
#  ...
#  [0.07471973 0.25305813 0.06753028 ... 0.22963948 0.94217271 0.31230913]
#  [0.08183843 0.27716749 0.07396403 ... 0.2515177  1.03193541 0.34206346]
#  [0.05681742 0.19242723 0.05135051 ... 0.17461952 0.71643492 0.23748212]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_low_RCP8_5_2040  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_low_RCP8_5_2040  | shape=(360, 165)
# ...
# V_ratio [[0.00920723 0.02917179 0.00738158 ... 0.02226103 0.10524253 0.03197103]
#  [0.06033543 0.19116414 0.04837184 ... 0.14587761 0.68965937 0.20950771]
#  [0.00444391 0.01407989 0.00356275 ... 0.01074438 0.05079575 0.01543095]
#  ...
#  [0.11227291 0.35572056 0.09001091 ... 0.27145083 1.28332655 0.3898545 ]
#  [0.13442401 0.42590313 0.10776978 ... 0.32500724 1.53652295 0.4667716 ]
#  [0.11591558 0.36726182 0.09293129 ... 0.28025798 1.32496376 0.40250323]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_high_RCP8_5_2030  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_high_RCP8_5_2030  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00709944 0.02404412 0.00641634 ... 0.02181902 0.08951981 0.02967381]
#  [0.06239703 0.21132404 0.05639326 ... 0.19176757 0.78679053 0.26080342]
#  [0.00602516 0.02040579 0.00544542 ... 0.01851738 0.07597375 0.0251836 ]
#  ...
#  [0.07471973 0.25305813 0.06753028 ... 0.22963948 0.94217271 0.31230913]
#  [0.08183843 0.27716749 0.07396403 ... 0.2515177  1.03193541 0.34206346]
#  [0.05681742 0.19242723 0.05135051 ... 0.17461952 0.71643492 0.23748212]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_high_RCP8_5_2040  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_high_RCP8_5_2040  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00834792 0.02703142 0.00849344 ... 0.02651793 0.10462722 0.03604731]
#  [0.08501404 0.27528416 0.08649596 ... 0.27005487 1.06550879 0.36710071]
#  [0.01057505 0.03424309 0.01075939 ... 0.03359261 0.13254056 0.04566432]
#  ...
#  [0.06149888 0.19913967 0.0625709  ... 0.19535682 0.77078561 0.26555946]
#  [0.06316329 0.20452918 0.06426432 ... 0.20064395 0.79164614 0.27274656]
#  [0.03765417 0.12192807 0.03831054 ... 0.11961193 0.47193209 0.16259519]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_high_RCP8_5_2050  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_high_RCP8_5_2050  | shape=(360, 165)
# row cities (source): ['Aba', 'Akesu', 'Alaer', 'Alashan', 'Aletai', 'Ali', 'Ankang', 'Anqing', 'Anshan', 'Anshun', 'Anyang', 'Baicheng', 'Baise', 'Baisha', 'Baishan', 'Baiyin', 'Baoding', 'Baoji', 'Baoshan', 'Baoting', 'Baotou', 'Bayanzhuoer', 'Bayinguoleng', 'Bazhong', 'Beihai', 'Beijing', 'Bengbu', 'Benxi', 'Bijie', 'Binnzhou', 'Binzhou', 'Boertalameng', 'Bozhou', 'Cangzhou', 'Changchun', 'Changde', 'Changdu', 'Changji', 'Changjiang', 'Changsha', 'Changzhi', 'Changzhou', 'Chaoyang', 'Chaozhou', 'Chengde', 'Chengdu', 'Chengmai', 'Chifeng', 'Chizhou', 'Chongqing', 'Chongzuo', 'Chuxiong', 'Chuzhou', 'Dali', 'Dalian', 'Dandong', 'Danzhou', 'Daqing', 'Datong', 'Daxinganling', 'Dazhou', 'Dehong', 'Deyang', 'Dezhou', 'Dingan', 'Dingxi', 'Diqing', 'Dongfang', 'Dongguan', 'Dongying', 'Eerduosi', 'Enshi', 'Ezhou', 'Fangchenggang', 'Foshan', 'Fushun', 'Fuuzhou', 'Fuxin', 'Fuyang', 'Fuzhou', 'Gannan', 'Ganzhou', 'Ganzi', 'Guangan', 'Guangyuan', 'Guangzhou', 'Guigang', 'Guilin', 'Guiyang', 'Guoluo', 'Guyuan', 'Haerbin', 'Haibei', 'Haidong', 'Haikou', 'Hainan', 'Haixi', 'Hami', 'Handan', 'Hangzhou', 'Hanzhong', 'Hebi', 'Hechi', 'Hefei', 'Hegang', 'Heihe', 'Hengshui', 'Hengyang', 'Hetian', 'Heyuan', 'Heze', 'Hezhou', 'Honghe', 'Huaian', 'Huaibei', 'Huaihua', 'Huainan', 'Huanggang', 'Huangnan', 'Huangshan', 'Huangshi', 'Huhehaote', 'Huizhou', 'Huludao', 'Hulunbeier', 'Huzhou', 'Jiamusi', 'Jian', 'Jiangmen', 'Jiaozuo', 'Jiaxing', 'Jiayuguan', 'Jieyang', 'Jilin', 'Jinan', 'Jinchang', 'Jincheng', 'Jingdezhen', 'Jingmen', 'Jingzhou', 'Jinhua', 'Jining', 'Jinzhong', 'Jinzhou', 'Jiujiang', 'Jiuquan', 'Jixi', 'Jiyuan', 'Kaifeng', 'Kashi', 'Kelamayi', 'Kezilesu', 'Kunming', 'Laibin', 'Langfang', 'Lanzhou', 'Lasa', 'Ledong', 'Leshan', 'Liangshan', 'Lianyungang', 'Liaocheng', 'Liaoyang', 'Liaoyuan', 'Lijiang', 'Lincang', 'Linfen', 'Lingao', 'Lingshui', 'Linxia', 'Linyi', 'Linzhi', 'Lishui', 'Liuan', 'Liupanshui', 'Liuzhou', 'Longnan', 'Longyan', 'Loudi', 'Luohe', 'Luoyang', 'Luzhou', 'Lvliang', 'Maanshan', 'Maoming', 'Meishan', 'Meizhou', 'Mianyang', 'Mudanjiang', 'Nanchang', 'Nanchong', 'Nanjing', 'Nanning', 'Nanping', 'Nantong', 'Nanyang', 'Naqu', 'Neijiang', 'Ningbo', 'Ningde', 'Nujiang', 'Panjin', 'Panzhihua', 'Pingdingshan', 'Pingliang', 'Pingxiang', 'Puer', 'Putian', 'Puyang', 'Qiandongnan', 'Qianjiang', 'Qiannan', 'Qianxinan', 'Qingdao', 'Qingyang', 'Qingyuan', 'Qinhuangdao', 'Qinzhou', 'Qionghai', 'Qiongzhong', 'Qiqihaer', 'Qitaihe', 'Quanzhou', 'Qujing', 'Quzhou', 'Rikaze', 'Rizhao', 'Sanmenxia', 'Sanming', 'Sanya', 'Shanghai', 'Shangluo', 'Shangqiu', 'Shangrao', 'Shannan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shaotong', 'Shaoxing', 'Shaoyang', 'Shennongjia', 'Shenyang', 'Shenzhen', 'Shihezi', 'Shijiazhuang', 'Shiyan', 'Shizuishan', 'Shuangyashan', 'Shuozhou', 'Siping', 'Songyuan', 'Suihua', 'Suining', 'Suizhou', 'Suuzhou', 'Suzhou', 'Tacheng', 'Taian', 'Taiizhou', 'Taiyuan', 'Taizhou', 'Tangshan', 'Tianjin', 'Tianmen', 'Tianshui', 'Tieling', 'Tongchuan', 'Tonghua', 'Tongliao', 'Tongling', 'Tongren', 'Tulufan', 'Tumushuke', 'Tunchang', 'Wanning', 'Weifang', 'Weihai', 'Weinan', 'Wenchang', 'Wenshan', 'Wenzhou', 'Wuhai', 'Wuhan', 'Wuhu', 'Wujiaqu', 'Wulanchabu', 'Wulumuqi', 'Wuwei', 'Wuxi', 'Wuzhishan', 'Wuzhong', 'Wuzhou', 'Xiamen', 'Xian', 'Xiangfan', 'Xiangtan', 'Xiangxi', 'Xianning', 'Xiantao', 'Xianyang', 'Xiaogan', 'Xilinguole', 'Xingan', 'Xingtai', 'Xining', 'Xinxiang', 'Xinyang', 'Xinyu', 'Xinzhou', 'Xishuangbanna', 'Xiuqian', 'Xuancheng', 'Xuchang', 'Xuzhou', 'Yaan', 'Yanan', 'Yanbian', 'Yancheng', 'Yangjiang', 'Yangquan', 'Yangzhou', 'Yantai', 'Yibin', 'Yichang', 'Yichun', 'Yiichun', 'Yili', 'Yinchuan', 'Yingkou', 'Yingtan', 'Yiyang', 'Yongzhou', 'Yueyang', 'Yulin', 'Yuncheng', 'Yunfu', 'Yushu', 'Yuulin', 'Yuxi', 'Zaozhuang', 'Zhangjiajie', 'Zhangjiakou', 'Zhangye', 'Zhangzhou', 'Zhanjiang', 'Zhaoqing', 'Zhengzhou', 'Zhenjiang', 'Zhongshan', 'Zhongwei', 'Zhoukou', 'Zhoushan', 'Zhuhai', 'Zhumadian', 'Zhuzhou', 'Zibo', 'Zigong', 'Ziyang' ...
# V_ratio [[0.00804322 0.02818522 0.008237   ... 0.0360983  0.11738097 0.04407837]
#  [0.10764355 0.37720677 0.11023689 ... 0.48310866 1.57092621 0.58990708]
#  [0.01258634 0.04410533 0.01288957 ... 0.05648803 0.18368233 0.06897555]
#  ...
#  [0.03965583 0.13896278 0.04061121 ... 0.17797698 0.5787284  0.21732146]
#  [0.03697711 0.12957597 0.03786796 ... 0.16595479 0.53963581 0.20264159]
#  [0.00661772 0.02318997 0.00677716 ... 0.02970062 0.09657761 0.03626639]]
# ✅ a_ij matrix saved: earlypeak_NZ_CL_high_RCP8_5_2060  | shape=(360, 165)
# ✅ Patient flow matrix saved: earlypeak_NZ_CL_high_RCP8_5_2060  | shape=(360, 165)

# %%
##---- Average across fer and rcp scenarios ----------
import pandas as pd
import numpy as np
import os, glob

# ===== Paths =====
OUT_DIR = "/Volumes/UCL/论文工作/空气污染/cross_flow_truncated"
AIJ_DIR = os.path.join(OUT_DIR, "aij_results")
FLOW_DIR = os.path.join(OUT_DIR, "flow_results")


AVG_DIR = os.path.join(OUT_DIR, "averaged_results")
os.makedirs(os.path.join(AVG_DIR, "aij_avg"), exist_ok=True)
os.makedirs(os.path.join(AVG_DIR, "flow_avg"), exist_ok=True)

# ===== Scenario sets =====
air_scenarios = ['earlypeak_NZ_CL']
fer_scenarios = ['low', 'mid', 'high']
rcp_scenarios = ['RCP2_6', 'RCP4_5', 'RCP8_5']
years = list(range(2020, 2061, 10))


for air in air_scenarios:
    for year in years:
        
       
        aij_matrices = []
        flow_matrices = []
        
        for fer in fer_scenarios:
            for rcp in rcp_scenarios:
                tag = f"{air}_{fer}_{rcp}_{year}"
                
    
                aij_path = os.path.join(AIJ_DIR, f"aij_rowprob_{tag}.csv")
                if os.path.exists(aij_path):
                    df_aij = pd.read_csv(aij_path, index_col=0)
                    aij_matrices.append(df_aij)
                else:
                    print(f"⚠️ Missing aij file: {aij_path}")
                
   
                flow_path = os.path.join(FLOW_DIR, f"flow_patientnum_{tag}.csv")
                if os.path.exists(flow_path):
                    df_flow = pd.read_csv(flow_path, index_col=0)
                    flow_matrices.append(df_flow)
                else:
                    print(f"⚠️ Missing flow file: {flow_path}")
        

        if len(aij_matrices) > 0:
            
            aij_avg = sum(aij_matrices) / len(aij_matrices)
            

            avg_tag = f"avg_{air}_{year}"
            aij_avg.to_csv(
                os.path.join(AVG_DIR, f"aij_avg/aij_rowprob_{avg_tag}.csv"),
                float_format="%.8g"
            )
            print(f"✅ Averaged a_ij saved: {avg_tag} | n_scenarios={len(aij_matrices)} | shape={aij_avg.shape}")
        else:
            print(f"⚠️ No a_ij matrices found for {air}_{year}")
        

        if len(flow_matrices) > 0:
            flow_avg = sum(flow_matrices) / len(flow_matrices)
            
            flow_avg.to_csv(
                os.path.join(AVG_DIR, f"flow_avg/flow_patientnum_{avg_tag}.csv"),
                float_format="%.8g"
            )
            print(f"✅ Averaged flow saved: {avg_tag} | n_scenarios={len(flow_matrices)} | shape={flow_avg.shape}")
        else:
            print(f"⚠️ No flow matrices found for {air}_{year}")
# Out:
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_low_RCP2_6_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_low_RCP2_6_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_low_RCP4_5_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_low_RCP4_5_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_low_RCP8_5_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_low_RCP8_5_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_mid_RCP2_6_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_mid_RCP2_6_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_mid_RCP8_5_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_mid_RCP8_5_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_high_RCP2_6_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_high_RCP2_6_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_high_RCP4_5_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_high_RCP4_5_2020.csv
# ⚠️ Missing aij file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/aij_results/aij_rowprob_earlypeak_NZ_CL_high_RCP8_5_2020.csv
# ⚠️ Missing flow file: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/flow_results/flow_patientnum_earlypeak_NZ_CL_high_RCP8_5_2020.csv
# ✅ Averaged a_ij saved: avg_earlypeak_NZ_CL_2020 | n_scenarios=1 | shape=(360, 165)
# ✅ Averaged flow saved: avg_earlypeak_NZ_CL_2020 | n_scenarios=1 | shape=(360, 165)
# ✅ Averaged a_ij saved: avg_earlypeak_NZ_CL_2030 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged flow saved: avg_earlypeak_NZ_CL_2030 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged a_ij saved: avg_earlypeak_NZ_CL_2040 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged flow saved: avg_earlypeak_NZ_CL_2040 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged a_ij saved: avg_earlypeak_NZ_CL_2050 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged flow saved: avg_earlypeak_NZ_CL_2050 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged a_ij saved: avg_earlypeak_NZ_CL_2060 | n_scenarios=9 | shape=(360, 165)
# ✅ Averaged flow saved: avg_earlypeak_NZ_CL_2060 | n_scenarios=9 | shape=(360, 165)
#
# ============================================================
# 平均计算完成！结果保存在: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/averaged_results
# - a_ij 平均矩阵: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/averaged_results/aij_avg
# - flow 平均矩阵: /Volumes/UCL/论文工作/空气污染/cross_flow_truncated/averaged_results/flow_avg

# %%
##---- Calculate city-level net pressure ----------
import pandas as pd
import numpy as np
from pathlib import Path

# ===== Paths =====
FLOW_DIR  = Path("/Volumes/UCL/论文工作/空气污染/cross_flow_truncated/averaged_results/flow_avg")
LOCAL_DIR = Path("/Volumes/UCL/论文工作/空气污染/health_burden/air_scenarios_5/city_patient_sum")
OUTPUT_DIR = Path("/Volumes/UCL/论文工作/空气污染/net_pressure_results")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# ===== Scenarios =====
SCENARIO = "earlypeak_NZ_CL"
years = list(range(2020, 2061, 10))

# ===== Main loop =====
for year in years:
    
    # --- 1. reading flow matrix ---
    flow_path = FLOW_DIR / f"flow_patientnum_avg_{SCENARIO}_{year}.csv"
    if not flow_path.exists():
        print(f"⚠️ Flow file not found: {flow_path}")
        continue
    
    flow_matrix = pd.read_csv(flow_path, index_col=0)
    flow_matrix.index = flow_matrix.index.str.strip()
    flow_matrix.columns = flow_matrix.columns.str.strip()
    

    np.fill_diagonal(flow_matrix.values, 0)
    
    # --- 2. calculate net inflow or outflow ---

    inflow = flow_matrix.sum(axis=0)
    outflow = flow_matrix.sum(axis=1)

    all_cities = inflow.index.union(outflow.index)
    inflow = inflow.reindex(all_cities, fill_value=0)
    outflow = outflow.reindex(all_cities, fill_value=0)
    
    net_inflow = inflow - outflow
    
    # --- 3. reading local patients ---
    local_path = LOCAL_DIR / f"citysum_{SCENARIO}_{year}.csv"
    if not local_path.exists():
        print(f"⚠️ Local file not found: {local_path}")
        continue
    
    local_df = pd.read_csv(local_path)
    local_df["city"] = local_df["city"].str.strip()
    local_patients = local_df.groupby("city")["local_patient"].sum()
    
    # --- 4. calculate net pressure ---
    common_cities = net_inflow.index.intersection(local_patients.index)
    
    result_df = pd.DataFrame({
        "city": common_cities,
        "local_patients": local_patients[common_cities].values,
        "inflow": inflow[common_cities].values,
        "outflow": outflow[common_cities].values,
        "net_inflow": net_inflow[common_cities].values,
        "net_pressure": (local_patients[common_cities] + net_inflow[common_cities]).values
        
    })
    
    result_df = result_df.sort_values("net_pressure", ascending=False).reset_index(drop=True)
    
    output_path = OUTPUT_DIR / f"net_pressure_{SCENARIO}_{year}.csv"
    result_df.to_csv(output_path, index=False, float_format="%.2f")
    
    # --- 6. 打印统计信息 ---
    print(f"{'='*70}")
    print(f"Year {year} | Cities: {len(result_df)}")
    print(f"{'='*70}")
    print(f"  Local patients total:     {result_df['local_patients'].sum():>12,.0f}")
    print(f"  Total inflow:             {result_df['inflow'].sum():>12,.0f}")
    print(f"  Total outflow:            {result_df['outflow'].sum():>12,.0f}")
    print(f"  Net inflow range:         [{result_df['net_inflow'].min():>8,.0f}, {result_df['net_inflow'].max():>8,.0f}]")
    print(f"  Net pressure range:       [{result_df['net_pressure'].min():>8,.0f}, {result_df['net_pressure'].max():>8,.0f}]")
    print(f"\nTop 5 cities by net pressure:")
    print(result_df.head(5)[["city", "local_patients", "net_inflow", "net_pressure"]].to_string(index=False))
    print(f"\nBottom 5 cities by net pressure:")
    print(result_df.tail(5)[["city", "local_patients", "net_inflow", "net_pressure"]].to_string(index=False))
    print(f"\n✅ Saved to: {output_path}\n")

print(f"\n{'='*70}")
print(f"All years processed! Results saved to: {OUTPUT_DIR}")
print(f"{'='*70}")
# Out:
# ======================================================================
# Year 2020 | Cities: 360
# ======================================================================
#   Local patients total:        1,403,909
#   Total inflow:                  223,990
#   Total outflow:                 223,990
#   Net inflow range:         [  -2,633,   21,216]
#   Net pressure range:       [    -144,   49,139]
#
# Top 5 cities by net pressure:
#      city  local_patients   net_inflow  net_pressure
#   Beijing     27923.02523 21215.872885  49138.898115
#  Shanghai     30164.91991 11570.281204  41735.201114
# Chongqing     31282.21689  6103.963191  37386.180081
#   Chengdu     22082.40823  5443.026056  27525.434286
#     Wuhan     12490.23579 12516.958592  25007.194382
#
# Bottom 5 cities by net pressure:
#     city  local_patients  net_inflow  net_pressure
# Lingshui       49.852017 -143.753205    -93.901188
#   Hainan       63.292946 -159.705900    -96.412954
# Tunchang       55.807810 -156.897977   -101.090167
#   Dingan       61.440617 -169.908426   -108.467809
# Zhongwei      375.683721 -519.760637   -144.076916
#
# ✅ Saved to: /Volumes/UCL/论文工作/空气污染/net_pressure_results/net_pressure_earlypeak_NZ_CL_2020.csv
#
# ======================================================================
# Year 2030 | Cities: 360
# ======================================================================
#   Local patients total:        1,496,492
#   Total inflow:                  243,792
#   Total outflow:                 243,792
#   Net inflow range:         [  -2,817,   13,029]
#   Net pressure range:       [    -204,   49,477]
#
# Top 5 cities by net pressure:
#      city  local_patients   net_inflow  net_pressure
#  Shanghai     37761.54361 11715.130285  49476.673895
#   Beijing     30274.00623 13029.004114  43303.010344
#   Tianjin     25746.72537  5357.401838  31104.127208
# Chongqing     22633.95346  5283.970276  27917.923736
#   Chengdu     23165.00065  4170.664571  27335.665221
#
# Bottom 5 cities by net pressure:
#     city  local_patients  net_inflow  net_pressure
#   Dingan       45.256056 -141.422840    -96.166784
# Tunchang       47.803377 -147.607584    -99.804207
#  Alashan       99.427022 -230.452395   -131.025373
#   Hainan       81.049773 -212.095331   -131.045558
# Zhongwei      423.739106 -627.937673   -204.198566
#
# ✅ Saved to: /Volumes/UCL/论文工作/空气污染/net_pressure_results/net_pressure_earlypeak_NZ_CL_2030.csv
#
# ======================================================================
# Year 2040 | Cities: 360
# ======================================================================
#   Local patients total:        1,423,524
#   Total inflow:                  238,348
#   Total outflow:                 238,348
#   Net inflow range:         [  -2,506,   13,322]
#   Net pressure range:       [    -253,   49,761]
#
# Top 5 cities by net pressure:
#      city  local_patients   net_inflow  net_pressure
#  Shanghai     38400.18331 11360.317530  49760.500840
#   Beijing     34705.36306 13321.653616  48027.016676
#   Tianjin     30543.85897  4640.242082  35184.101052
#   Chengdu     25342.92735  3470.245924  28813.173274
# Zhengzhou     18561.39976  5291.977110  23853.376870
#
# Bottom 5 cities by net pressure:
#     city  local_patients  net_inflow  net_pressure
# Tunchang       39.344069 -139.500034   -100.155965
# Lingshui       40.368236 -144.265868   -103.897632
#   Hainan       86.255691 -240.830953   -154.575262
#  Alashan      117.404564 -299.431854   -182.027290
# Zhongwei      412.984600 -665.747258   -252.762658
#
# ✅ Saved to: /Volumes/UCL/论文工作/空气污染/net_pressure_results/net_pressure_earlypeak_NZ_CL_2040.csv
#
# ======================================================================
# Year 2050 | Cities: 360
# ======================================================================
#   Local patients total:        1,338,019
#   Total inflow:                  231,834
#   Total outflow:                 231,834
#   Net inflow range:         [  -3,029,   13,108]
#   Net pressure range:       [    -329,   46,517]
#
# Top 5 cities by net pressure:
#      city  local_patients   net_inflow  net_pressure
#   Beijing     33409.38792 13107.983031  46517.370951
#  Shanghai     32836.98935 11398.637548  44235.626898
#   Tianjin     29853.32892  4356.356350  34209.685270
#   Chengdu     28251.84894  3254.494169  31506.343109
# Zhengzhou     21640.59072  4731.200792  26371.791512
#
# Bottom 5 cities by net pressure:
#     city  local_patients  net_inflow  net_pressure
# Huangnan       59.184412 -178.063661   -118.879249
#      Aba      278.898898 -400.951670   -122.052772
#   Hainan      109.126185 -331.806878   -222.680693
#  Alashan      145.084263 -414.835648   -269.751384
# Zhongwei      442.311784 -771.221779   -328.909995
#
# ✅ Saved to: /Volumes/UCL/论文工作/空气污染/net_pressure_results/net_pressure_earlypeak_NZ_CL_2050.csv
#
# ======================================================================
# Year 2060 | Cities: 360
# ======================================================================
#   Local patients total:        1,003,388
#   Total inflow:                  174,575
#   Total outflow:                 174,575
#   Net inflow range:         [  -4,545,   10,167]
#   Net pressure range:       [    -323,   39,355]
#
# Top 5 cities by net pressure:
#     city  local_patients   net_inflow  net_pressure
#  Beijing     29188.08338 10166.881015  39354.964395
# Shanghai     28501.42847  8698.803862  37200.232332
#  Tianjin     25373.38221  2901.112790  28274.495000
#  Chengdu     25756.26054  2184.354339  27940.614879
#  Suuzhou     24492.68748  -738.039794  23754.647686
#
# Bottom 5 cities by net pressure:
#     city  local_patients  net_inflow  net_pressure
#     Naqu       63.995227 -205.085796   -141.090569
# Huangnan       67.000117 -210.299185   -143.299068
#   Hainan      119.605165 -377.450425   -257.845260
#  Alashan      135.646818 -410.714161   -275.067343
# Zhongwei      410.018542 -733.372351   -323.353809
#
# ✅ Saved to: /Volumes/UCL/论文工作/空气污染/net_pressure_results/net_pressure_earlypeak_NZ_CL_2060.csv
#
#
# ======================================================================
# All years processed! Results saved to: /Volumes/UCL/论文工作/空气污染/net_pressure_results
# ======================================================================
